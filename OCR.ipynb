# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielACocolete/OCR/blob/main/OCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !sudo apt-get install -y tesseract-ocr-por
# !pip install pillow
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 3s (1,474 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# eng
# osd
# por

# %%
# Importar bibliotecas necessárias
import pytesseract
from PIL import Image
import requests
from io import BytesIO

indice = 1;

# imagem de exemplo
for i in range(1, 10):
  img = '/content/texto' + str(indice) + '.png'
  texto = pytesseract.image_to_string(img, lang='por')
  print(texto)
  indice = indice + 1
# Out:
# Eu poderia escrever um texto gigante
# cheio de palavras clichês falando o
# quanto eu gosto de ti e o quanto tu
# significa pra mim, mas sei que não
# preciso disso pra demonstrar todos os
# meus sentimentos por ti. Eu só preciso te
# agradecer por tudo o que tu fez e ainda
# faz por mim. Obrigada por estar...
#
# [cc DNS
#
# Texog Infinitop
# dentro de Mim.
#
# Escrevi textos aleatórios que por algum
# motivo insistem em sair, me inspirei em
# pessoas que deixaram livros com textos
# saborosissimos e que encantam pelo
# simples motivo de terem sidos escritos, é
# como se o sentimento e a emoção
# pudessem ser tocados.
#
# Ouso afirmar que ainda não escrevi tudo,
# pois essa é uma recente paixão que me
# deixa em êxtase. Entro numa sensação de
# pertencimento. Faço para eternizar o meu
# eu. Então escrevo e escrevo, até cansar,
# até retirar todas as palavras da minha
# cabeça.
#
#
#
# I
#
# DO
#
#
#
# 0067568
#
# 06
#
#
#
# e vamos LER?
#
# é
#
# i
# | ARAVÊ O RATO NA CASA
# ...
